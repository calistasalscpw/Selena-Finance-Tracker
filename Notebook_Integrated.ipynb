# %% [markdown]
# <a href="https://colab.research.google.com/github/calistasalscpw/Selena-Finance-Tracker/blob/risma/Notebook_Integrated.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **DATA ANALYSIS**

# %%
import numpy as np
import pandas as pd

# %%
adit_df = pd.read_csv("dataset_adit.csv")
adit_df.sample(20)
# Out:
#     ID            NOREK             TGL_TRAN          TGL_EFEKTIF  JAM_TRAN  \
# 59  10  479101005292506  2024-11-07 19:12:37  2024-11-07 19:12:37  191237.0
# 10   5  479101005292506  2024-02-28 20:09:07  2024-02-28 20:09:07  200907.0
# 40  13  479101005292506  2024-10-30 08:02:25  2024-10-30 08:02:25   80225.0
# 25   7  479101005292506  2024-08-21 06:23:21  2024-08-21 06:23:21   62321.0
# 58   9  479101005292506  2024-11-05 19:43:31  2024-11-05 19:43:31  194331.0
# 21   3  479101005292506  2024-08-20 12:08:35  2024-08-20 12:08:35  120835.0
# 13   8  479101005292506  2024-02-28 21:41:10  2024-02-28 21:41:10  214110.0
# 0    1  479101005292506  2024-01-29 23:16:47  2024-01-29 23:16:47  231647.0
# 67  18  479101005292506  2024-11-11 10:24:21  2024-11-11 10:24:21  102421.0
# 34   7  479101005292506  2024-10-28 10:40:52  2024-10-28 10:40:52  104052.0
# 9    4  479101005292506  2024-02-28 20:09:07  2024-02-28 20:09:07  200907.0
# 35   8  479101005292506  2024-10-29 13:19:05  2024-10-29 13:19:05  131905.0
# 28   1  479101005292506  2024-10-20 14:57:55  2024-10-20 14:57:55  145755.0
# 32   5  479101005292506  2024-10-23 12:32:09  2024-10-23 12:32:09  123209.0
# 37  10  479101005292506  2024-10-30 08:00:24  2024-10-30 08:00:24   80024.0
# 3    4  479101005292506  2024-01-30 08:43:32  2024-01-30 08:43:32   84332.0
# 14   1  479101005292506  2024-03-01 00:00:00  2024-03-01 00:00:00       NaN
# 22   4  479101005292506  2024-08-20 20:11:20  2024-08-20 20:11:20  201120.0
# 11   6  479101005292506  2024-02-28 20:15:16  2024-02-28 20:15:16  201516.0
# 72  23  479101005292506  2024-11-11 10:48:21  2024-11-11 10:48:21  104821.0
#
#           SEQ                                          DESK_TRAN  \
# 59  8009171.0  BFST0197529801 NBMB:BNINIDJA 20241107BRINIDJA0...
# 10    71437.0  BFST002501002620303 NBMB:AGTBIDJA 20240228BRIN...
# 40   101424.0  6013010855480076#754182244496#NBMB#TRFLA LA167...
# 25     2121.0                           601301085548007600051368
# 58     5649.0                           601301085548007600161859
# 21   144054.0  BFST479101005292506AHYARBACHTIA:BSMDIDJA 20240...
# 13   112650.0  BFST0014301560014856 NBMB:BTANIDJA 20240228BRI...
# 0     33048.0  NBMB NIKEN WIDYA TO SURATUN ESB:NBMB:0001500F:...
# 67   102833.0  6013010855480076#759730035489#NBMB#TRFMP LN 00...
# 34  9000009.0             TUNAI ; ESB:INDS:0002800D:9b0248a1d7a9
# 9     71437.0  BFST002501002620303 NBMB:AGTBIDJA 20240228BRIN...
# 35   105568.0  BFST479101005292506ADITYA DAFFA:BTANIDJA 20241...
# 28   104272.0  NBMB AMAT BIN ITA TO SURATUN ESB:NBMB:0001500F...
# 32  8024440.0  BFST8850786179 NBMB:CENAIDJA 20241023BRINIDJA0...
# 37    61415.0  BFST002501002620303 NBMB:AGTBIDJA 20241030BRIN...
# 3    102331.0  BFST002501002620303 NBMB:AGTBIDJA 20240130BRIN...
# 14        NaN                          Transaksi tidak ditemukan
# 22  7047524.0  DANA20240820018538963998ADITYADAFFAS WS_OB;202...
# 11   151566.0  NBMB SURATUN TO MIMI HILMIYAH ESB:NBMB:0001500...
# 72   143116.0  BFST2757514521 NBMB:CENAIDJA 20241111BRINIDJA0...
#
#     SALDO_AWAL_MUTASI  MUTASI_DEBET  MUTASI_KREDIT  SALDO_AKHIR_MUTASI GLSIGN  \
# 59          4291295.8      500000.0            0.0           3791295.8     Db
# 10           426547.8        2500.0            0.0            424047.8     Db
# 40          1413547.8        6500.0            0.0           1407047.8     Db
# 25           371547.8      300000.0            0.0             71547.8     Db
# 58          3291295.8           0.0      1000000.0           4291295.8     Cr
# 21            71547.8           0.0       350000.0            421547.8     Cr
# 13            74047.8        2500.0            0.0             71547.8     Db
# 0             61547.8           0.0      2735000.0           2796547.8     Cr
# 67          4120995.8      775000.0            0.0           3345995.8     Db
# 34           819047.8           0.0      4000000.0           4819047.8     Cr
# 9           3426547.8     3000000.0            0.0            426547.8     Db
# 35          4819047.8           0.0       800000.0           5619047.8     Cr
# 28           221547.8           0.0       800000.0           1021547.8     Cr
# 32           121547.8        2500.0            0.0            119047.8     Db
# 37          7619047.8     3000000.0            0.0           4619047.8     Db
# 3            296547.8        2500.0            0.0            294047.8     Db
# 14            71547.8           0.0            0.0             71547.8    NaN
# 22           421547.8           0.0       250000.0            671547.8     Cr
# 11           424047.8      200000.0            0.0            224047.8     Db
# 72          3086995.8        2500.0            0.0           3084495.8     Db
#
#        TRUSER  KODE_TRAN  KODE_TRAN_TELLER  \
# 59  8888435.0        2.0            9973.0
# 10  8888504.0        2.0            9973.0
# 40  8888286.0        2.0            8508.0
# 25  9966111.0        2.0            2501.0
# 58  9930505.0        1.0            8554.0
# 21  8888684.0        1.0            8154.0
# 13  8888259.0        2.0            9973.0
# 0   8888168.0        1.0            8506.0
# 67  8888291.0        2.0            8508.0
# 34  4791053.0        1.0            2117.0
# 9   8888504.0        2.0            9973.0
# 35  8888692.0        1.0            8154.0
# 28  8888117.0        1.0            8506.0
# 32  8888409.0        2.0            9973.0
# 37  8888371.0        2.0            9973.0
# 3   8888513.0        2.0            9973.0
# 14        NaN        NaN               NaN
# 22   371851.0        5.0            8700.0
# 11  8888422.0        2.0            8506.0
# 72  8888254.0        2.0            9973.0
#
#                                       TRREMK  \
# 59              BFST0197529801 NBMB:BNINIDJA
# 10         BFST002501002620303 NBMB:AGTBIDJA
# 40  6013010855480076#754182244496#NBMB#TRFLA
# 25                  601301085548007600051368
# 58                  601301085548007600161859
# 21  BFST479101005292506AHYARBACHTIA:BSMDIDJA
# 13        BFST0014301560014856 NBMB:BTANIDJA
# 0                NBMB NIKEN WIDYA TO SURATUN
# 67  6013010855480076#759730035489#NBMB#TRFMP
# 34                                       NaN
# 9          BFST002501002620303 NBMB:AGTBIDJA
# 35  BFST479101005292506ADITYA DAFFA:BTANIDJA
# 28              NBMB AMAT BIN ITA TO SURATUN
# 32              BFST8850786179 NBMB:CENAIDJA
# 37         BFST002501002620303 NBMB:AGTBIDJA
# 3          BFST002501002620303 NBMB:AGTBIDJA
# 14                                       NaN
# 22      DANA20240820018538963998ADITYADAFFAS
# 11             NBMB SURATUN TO MIMI HILMIYAH
# 72              BFST2757514521 NBMB:CENAIDJA
#
#                                       TLBDS1  \
# 59            ESB:NBMB:0008G00F:758244916029
# 10            ESB:NBMB:0008G00F:653734400121
# 40            ESB:NBMB:0005N00F:754182244496
# 25                                       NaN
# 58                                       NaN
# 21  ESB:BFST:0008N:20240820FASTIDJA010465322
# 13            ESB:NBMB:0008G00F:653769362596
# 0             ESB:NBMB:0001500F:641894918038
# 67            ESB:NBMB:0007N00F:759730035489
# 34            ESB:INDS:0002800D:9b0248a1d7a9
# 9             ESB:NBMB:0008G00F:653734400121
# 35  ESB:BFST:0008N:20241029FASTIDJA010267860
# 28            ESB:NBMB:0001500F:750054948280
# 32            ESB:NBMB:0008G00F:751255027737
# 37            ESB:NBMB:0008G00F:754181614360
# 3             ESB:NBMB:0008G00F:641979970180
# 14                                       NaN
# 22              ESB:T:0371851:S:0371892:WSOB
# 11            ESB:NBMB:0001500F:653736999075
# 72            ESB:NBMB:0008G00F:759740957843
#
#                                       TLBDS2  \
# 59            20241107BRINIDJA010O0281528965
# 10            20240228BRINIDJA010O0229611484
# 40  LA167891050001200093NBMB6013010855480076
# 25                                       NaN
# 58                                       NaN
# 21            20240820BSMDIDJA010O0259276187
# 13            20240228BRINIDJA010O0229925505
# 0                                        NaN
# 67   LN 0001601023286036NBMB6013010855480076
# 34                                   TUNAI ;
# 9             20240228BRINIDJA010O0229611484
# 35            20241029BTANIDJA010O0241997162
# 28                                       NaN
# 32            20241023BRINIDJA010O0291126966
# 37            20241030BRINIDJA010O0244718555
# 3             20240130BRINIDJA010O0227521528
# 14                                       NaN
# 22          WS_OB;20240820018538963998;72133
# 11                                       NaN
# 72            20241111BRINIDJA010O0226253468
#
#                                REMARK_CUSTOM
# 59              BFST0197529801 NBMB:BNINIDJA
# 10         BFST002501002620303 NBMB:AGTBIDJA
# 40  6013010855480076#754182244496#NBMB#TRFLA
# 25                  601301085548007600051368
# 58                             Setoran Tunai
# 21  BFST479101005292506AHYARBACHTIA:BSMDIDJA
# 13        BFST0014301560014856 NBMB:BTANIDJA
# 0        Transfer Dari Niken Widya via BRImo
# 67  6013010855480076#759730035489#NBMB#TRFMP
# 34    TUNAI ; ESB:INDS:0002800D:9b0248a1d7a9
# 9          BFST002501002620303 NBMB:AGTBIDJA
# 35  BFST479101005292506ADITYA DAFFA:BTANIDJA
# 28      Transfer Dari Amat Bin Ita via BRImo
# 32              BFST8850786179 NBMB:CENAIDJA
# 37         BFST002501002620303 NBMB:AGTBIDJA
# 3          BFST002501002620303 NBMB:AGTBIDJA
# 14                                       NaN
# 22      DANA20240820018538963998ADITYADAFFAS
# 11       Transfer Ke Mimi Hilmiyah via BRImo
# 72              BFST2757514521 NBMB:CENAIDJA

# %%
alus_df = pd.read_csv("dataset_alus.csv")
alus_df.sample(20)
# Out:
#      ID           NOREK             TGL_TRAN          TGL_EFEKTIF  JAM_TRAN  \
# 14   15  12301083861508  2024-01-23 07:40:00       1/23/2024 0:00     74045
# 164   7  12301083861508  2024-08-09 06:39:51  2024-08-09 00:00:00     63951
# 217   7  12301083861508  2024-10-13 11:06:41  2024-10-13 00:00:00    110641
# 105  17  12301083861508  2024-05-20 00:00:00  2024-05-20 00:00:00         0
# 62   22  12301083861508  2024-03-28 23:59:59  2024-03-28 00:00:00    235959
# 203  19  12301083861508  2024-09-19 16:38:32  2024-09-19 00:00:00    163832
# 123   8  12301083861508  2024-06-20 23:59:59  2024-06-20 00:00:00    235959
# 93    5  12301083861508  2024-05-07 13:40:04  2024-05-07 00:00:00    134004
# 242   6  12301083861508  2024-11-07 18:02:00       11/7/2024 0:00    180229
# 150  24  12301083861508  2024-07-30 08:36:22  2024-07-30 00:00:00     83622
# 11   12  12301083861508  2024-01-19 08:28:00       1/19/2024 0:00     82822
# 41    1  12301083861508  2024-03-01 14:46:36  2024-03-01 00:00:00    144636
# 163   6  12301083861508  2024-08-08 18:58:20  2024-08-08 00:00:00    185820
# 83   21  12301083861508  2024-04-26 21:01:52  2024-04-26 00:00:00    210152
# 223  13  12301083861508  2024-10-19 16:50:37  2024-10-19 00:00:00    165037
# 54   14  12301083861508  2024-03-20 00:00:00  2024-03-20 00:00:00         0
# 15   16  12301083861508  2024-01-23 12:07:00       1/23/2024 0:00    120706
# 82   20  12301083861508  2024-04-26 21:01:52  2024-04-26 00:00:00    210152
# 77   15  12301083861508  2024-04-12 08:53:01  2024-04-12 00:00:00     85301
# 229  19  12301083861508  2024-10-20 19:08:24  2024-10-20 00:00:00    190824
#
#          SEQ                                          DESK_TRAN  \
# 14   5084097  EDC DEYA DAMAYANTI TO ALUSTINA SUCI M FROM4329...
# 164    66160  WBNK DEYA DAMAYANTI TO TO ALUSTINA SUCI FROM34...
# 217  8023269  PUL-SIM 081286178536NBMB5221840817338040 ESB:N...
# 105        0                                    Monthly Fee ATM
# 62         0            081286178536|1SMS|23/03/2024-23/03/2024
# 203   128959  BFST18101610149678 NBMB:BTANIDJA 20240919BRINI...
# 123        0                                          Admin Fee
# 93    106527  BRIVA88810085779048190NBMBDNID MISXXX AU BRIVA...
# 242   166953  BRIVA88810081286178536NBMBDNID ALUXXXXX BRIVA ...
# 150    61860  BFST012301083861508ALFIA MEILAN:PDJBIDJA ESB:B...
# 11     82098  BRIVA88810089609954495NBMBDNID YESXXX AD BRIVA...
# 41   9645652  WBNK DEYA DAMAYANTI TO TO ALUSTINA SUCI FROM43...
# 163  9009706  BRIVA112081286178536NBMBaXXXXXXXXXXi BRIVA 112...
# 83    132415  PUL-SIM 081286178536NBMB5221840817338040 ESB:N...
# 223  1644431                       6013011130242596000000000624
# 54         0                                    Monthly Fee ATM
# 15   5989475  EDC DEYA DAMAYANTI TO ALUSTINA SUCI M FROM4329...
# 82    132415  PUL-SIM 081286178536NBMB5221840817338040 ESB:N...
# 77    102236  NBMB DEYA DAMAYANTI TO ALUSTINA SUCI MAN ESB:N...
# 229   126255  BRIVA88810085214035324NBMBDNID LUTXXX SI BRIVA...
#
#      SALDO_AWAL_MUTASI  MUTASI_DEBET  MUTASI_KREDIT  SALDO_AKHIR_MUTASI  \
# 14            422000.0           0.0      5000000.0           5422000.0
# 164           968500.0           0.0      2000000.0           2968500.0
# 217           414450.0        1500.0            0.0            412950.0
# 105          1187250.0        1000.0            0.0           1186250.0
# 62           1238000.0         750.0            0.0           1237250.0
# 203           525200.0        2500.0            0.0            522700.0
# 123           544750.0        6000.0            0.0            538750.0
# 93           1539750.0       26500.0            0.0           1513250.0
# 242           560700.0       50000.0            0.0            510700.0
# 150          7795500.0           0.0      1000000.0           8795500.0
# 11            462500.0       33500.0            0.0            429000.0
# 41            251000.0           0.0      1200000.0           1451000.0
# 163           998500.0       30000.0            0.0            968500.0
# 83           2711500.0        1500.0            0.0           2710000.0
# 223           737950.0      100000.0            0.0            637950.0
# 54            318500.0        1000.0            0.0            317500.0
# 15           5422000.0           0.0       500000.0           5922000.0
# 82           2741500.0       30000.0            0.0           2711500.0
# 77            769750.0           0.0      2000000.0           2769750.0
# 229           591450.0       80000.0            0.0            511450.0
#
#     GLSIGN   TRUSER  KODE_TRAN  KODE_TRAN_TELLER  \
# 14      Cr   852416          1            8506.0
# 164     Cr  0888136          1            8506.0
# 217     Db  8888123          2            8508.0
# 105     Db      NaN        452               NaN
# 62      Db   DDY402        582               NaN
# 203     Db  8888561          2            9973.0
# 123     Db      NaN        453               NaN
# 93      Db  8888019          4            6669.0
# 242     Db  8888215          4            6669.0
# 150     Cr  8888630          1            8154.0
# 11      Db  8888530          4            6669.0
# 41      Cr  0888907          1            8506.0
# 163     Db  8888176          4            6669.0
# 83      Db  8888588          2            8508.0
# 223     Db  0888294          2            9992.0
# 54      Db      NaN        452               NaN
# 15      Cr   852416          1            8506.0
# 82      Db  8888588          2            8508.0
# 77      Cr  8888109          1            8506.0
# 229     Db  8888539          4            6669.0
#
#                                        TRREMK  \
# 14      EDC DEYA DAMAYANTI TO ALUSTINA SUCI M
# 164   WBNK DEYA DAMAYANTI TO TO ALUSTINA SUCI
# 217  PUL-SIM 081286178536NBMB5221840817338040
# 105                                       NaN
# 62    081286178536|1SMS|23/03/2024-23/03/2024
# 203          BFST18101610149678 NBMB:BTANIDJA
# 123                                       NaN
# 93   BRIVA88810085779048190NBMBDNID MISXXX AU
# 242   BRIVA88810081286178536NBMBDNID ALUXXXXX
# 150  BFST012301083861508ALFIA MEILAN:PDJBIDJA
# 11   BRIVA88810089609954495NBMBDNID YESXXX AD
# 41    WBNK DEYA DAMAYANTI TO TO ALUSTINA SUCI
# 163      BRIVA112081286178536NBMBaXXXXXXXXXXi
# 83   PUL-SIM 081286178536NBMB5221840817338040
# 223              6013011130242596000000000624
# 54                                        NaN
# 15      EDC DEYA DAMAYANTI TO ALUSTINA SUCI M
# 82   PUL-SIM 081286178536NBMB5221840817338040
# 77   NBMB DEYA DAMAYANTI TO ALUSTINA SUCI MAN
# 229  BRIVA88810085214035324NBMBDNID LUTXXX SI
#
#                                        TLBDS1  \
# 14   FROM432901018417534 TO012301083861508EDC
# 164  FROM346301031725533 TO012301083861508WBN
# 217            ESB:NBMB:0100101C:747039490198
# 105                                       NaN
# 62                                        NaN
# 203            ESB:NBMB:0008G00F:736714814134
# 123                                       NaN
# 93             ESB:NBMB:0200200P:681638831460
# 242            ESB:NBMB:0200200P:758211987117
# 150  ESB:BFST:0008N:20240730FASTIDJA010625917
# 11             ESB:NBMB:0200200P:637489267755
# 41   FROM432901018417534 TO012301083861508WBN
# 163            ESB:NBMB:0200200P:719544354995
# 83             ESB:NBMB:0100101C:677274693052
# 223                                       NaN
# 54                                        NaN
# 15   FROM432901018417534 TO012301083861508EDC
# 82             ESB:NBMB:0100101C:677274693052
# 77             ESB:NBMB:0001500F:672015337408
# 229            ESB:NBMB:0200200P:750148493209
#
#                                        TLBDS2  \
# 14                                        NaN
# 164                                       NaN
# 217                                       NaN
# 105                                       NaN
# 62                                        NaN
# 203            20240919BRINIDJA010O0236668656
# 123                                       NaN
# 93   BRIVA 88810085779048190NBMBDNID MISXXX A
# 242  BRIVA 88810081286178536NBMBDNID ALUXXXXX
# 150                                       NaN
# 11   BRIVA 88810089609954495NBMBDNID YESXXX A
# 41                                        NaN
# 163     BRIVA 112081286178536NBMBaXXXXXXXXXXi
# 83                                        NaN
# 223                                       NaN
# 54                                        NaN
# 15                                        NaN
# 82                                        NaN
# 77                                        NaN
# 229  BRIVA 88810085214035324NBMBDNID LUTXXX S
#
#                                          REMARK_CUSTOM
# 14                Transfer Dari Deya Damayanti via EDC
# 164           Transfer Dari Deya Damayanti via BRILink
# 217           Beli Pulsa Simpati 0812xxxx536 via BRImo
# 105                                    Monthly Fee ATM
# 62          Biaya SMS Notifikasi Sejumlah 1 Notifikasi
# 203                   BFST18101610149678 NBMB:BTANIDJA
# 123                                          Admin Fee
# 93         Top Up DANA MISXXX AU 0857xxxx190 via BRImo
# 242         Top Up DANA ALUXXXXX 0812xxxx536 via BRImo
# 150           BFST012301083861508ALFIA MEILAN:PDJBIDJA
# 11         Top Up DANA YESXXX AD 0896xxxx495 via BRImo
# 41            Transfer Dari Deya Damayanti via BRILink
# 163  Top Up Shopee  aXXXXXXXXXXi 0812xxxx536 via BRImo
# 83            Beli Pulsa Simpati 0812xxxx536 via BRImo
# 223                       6013011130242596000000000624
# 54                                     Monthly Fee ATM
# 15                Transfer Dari Deya Damayanti via EDC
# 82            Beli Pulsa Simpati 0812xxxx536 via BRImo
# 77              Transfer Dari Deya Damayanti via BRImo
# 229        Top Up DANA LUTXXX SI 0852xxxx324 via BRImo

# %%
amin_df = pd.read_csv("dataset_amin.csv")
amin_df.sample(20)
# Out:
#      ID            NOREK             TGL_TRAN          TGL_EFEKTIF  JAM_TRAN  \
# 69   14  678701037253531  2023-12-29 11:10:27  2023-12-29 00:00:00    111027
# 88   15  678701037253531  2024-01-16 00:00:00  2024-01-16 00:00:00         0
# 90   17  678701037253531  2024-01-23 10:50:21  2024-01-23 00:00:00    105021
# 34   12  678701037253531  2023-08-29 15:19:20  2023-08-29 00:00:00    151920
# 86   13  678701037253531  2024-01-14 20:21:00  2024-01-14 00:00:00    202100
# 3     4  678701037253531  2023-09-04 13:23:05  2023-09-04 00:00:00    132305
# 73   18  678701037253531  2023-12-30 20:38:53  2023-12-30 00:00:00    203853
# 68   13  678701037253531  2023-12-29 07:05:22  2023-12-29 00:00:00     70522
# 182   2  678701037253531  2024-06-01 21:36:15  2024-06-01 00:00:00    213615
# 176  24  678701037253531  2024-05-22 07:36:02  2024-05-22 00:00:00     73602
# 142  20  678701037253531  2024-04-16 00:00:00  2024-04-16 00:00:00         0
# 14   15  678701037253531  2023-09-22 23:59:59  2023-09-22 00:00:00    235959
# 113   6  678701037253531  2024-03-07 19:08:05  2024-03-07 00:00:00    190805
# 242  15  678701037253531  2024-08-16 23:59:59  2024-08-16 00:00:00    235959
# 218  12  678701037253531  2024-07-09 14:15:32  2024-07-09 00:00:00    141532
# 243  16  678701037253531  2024-08-18 07:06:05  2024-08-18 00:00:00     70605
# 99    8  678701037253531  2024-02-04 11:04:49  2024-02-04 00:00:00    110449
# 165  13  678701037253531  2024-05-09 09:36:15  2024-05-09 00:00:00     93615
# 210   4  678701037253531  2024-07-02 11:05:42  2024-07-02 00:00:00    110542
# 157   5  678701037253531  2024-05-04 21:44:42  2024-05-04 00:00:00    214442
#
#          SEQ                                          DESK_TRAN  \
# 69     29212                 089529961557 00056027 000000029212
# 88         0                                    Monthly Fee ATM
# 90    143358  BFST8930666999 NBMB:CENAIDJA 20240123BRINIDJA0...
# 34     84724  BRIVA88810081219556562NBMBDNID FERXX BRIVA 888...
# 86     14402                 089529961557 00050885 000000014402
# 3       4242                 089529961557 00450971 000000004242
# 73     30513                 089529961557 00861563 000000030513
# 68      1512  NBMB NABILA SANDRA TO AMIN AFIF RAFI'I ESB:NBM...
# 182        0            089529961557|1SMS|28/05/2024-28/05/2024
# 176        0            089529961557|3SMS|18/05/2024-18/05/2024
# 142        0                                    Monthly Fee ATM
# 14         0            089529961557|1SMS|15/09/2023-15/09/2023
# 113    50686  BRIVA3379089529961557NBMBAmin Afif Rafi BRIVA ...
# 242        0                                          Admin Fee
# 218   164037  BRIVA211410089529961557NBMBAMIN AFIF RAF ESB:N...
# 243        0            089529961557|1SMS|14/08/2024-14/08/2024
# 99      3740  BFST8930393500 NBMB:CENAIDJA 20240204BRINIDJA0...
# 165   123168  NBMB AMIN AFIF RAFI TO NABILA SANDRA KUR ESB:N...
# 210  9064212  QRIS704267703781#9360000210043076322 ESB:NBMB:...
# 157   112807  NBMB AMIN AFIF RAFI TO AINI ZULFA NAWAL ESB:NB...
#
#      SALDO_AWAL_MUTASI  MUTASI_DEBET  MUTASI_KREDIT  SALDO_AKHIR_MUTASI  \
# 69           645129.27      100000.0            0.0           545129.27
# 88           126268.27        2500.0            0.0           123768.27
# 90           118268.27       58000.0            0.0            60268.27
# 34           196020.27      164000.0            0.0            32020.27
# 86           246268.27      100000.0            0.0           146268.27
# 3           1132020.27      100000.0            0.0          1032020.27
# 73           196129.27      100000.0            0.0            96129.27
# 68           195129.27           0.0       450000.0           645129.27
# 182          793050.27         750.0            0.0           792300.27
# 176         2040904.27        2250.0            0.0          2038654.27
# 142         2039508.27        2500.0            0.0          2037008.27
# 14           146990.27         500.0            0.0           146490.27
# 113          535319.27      145000.0            0.0           390319.27
# 242           43014.27        5500.0            0.0            37514.27
# 218          743626.27       50000.0            0.0           693626.27
# 243           37514.27         750.0            0.0            36764.27
# 99          1632283.27      332000.0            0.0          1300283.27
# 165         1673104.27       59200.0            0.0          1613904.27
# 210         1926135.27      239100.0            0.0          1687035.27
# 157         1837654.27       10000.0            0.0          1827654.27
#
#     GLSIGN   TRUSER  KODE_TRAN  KODE_TRAN_TELLER  \
# 69      Db  9854029          2            2501.0
# 88      Db      NaN        452               NaN
# 90      Db  8888349          2            9973.0
# 34      Db  8888216          4            6669.0
# 86      Db  9854356          2            2501.0
# 3       Db  9854075          2            2501.0
# 73      Db  9854674          2            2501.0
# 68      Cr  8888552          1            8506.0
# 182     Db  BRIMDBT        582               NaN
# 176     Db  BRIMDBT        582               NaN
# 142     Db      NaN        452               NaN
# 14      Db   DDY402        582               NaN
# 113     Db  8888220          4            6669.0
# 242     Db      NaN        453               NaN
# 218     Db  8888075          4            6669.0
# 243     Db  BRIMDBT        582               NaN
# 99      Db  8888149          2            9973.0
# 165     Db  8888589          2            8506.0
# 210     Db  8888252          2            8508.0
# 157     Db  8888438          2            8506.0
#
#                                        TRREMK  \
# 69         089529961557 00056027 000000029212
# 88                                        NaN
# 90               BFST8930666999 NBMB:CENAIDJA
# 34       BRIVA88810081219556562NBMBDNID FERXX
# 86         089529961557 00050885 000000014402
# 3          089529961557 00450971 000000004242
# 73         089529961557 00861563 000000030513
# 68     NBMB NABILA SANDRA TO AMIN AFIF RAFI'I
# 182   089529961557|1SMS|28/05/2024-28/05/2024
# 176   089529961557|3SMS|18/05/2024-18/05/2024
# 142                                       NaN
# 14    089529961557|1SMS|15/09/2023-15/09/2023
# 113   BRIVA3379089529961557NBMBAmin Afif Rafi
# 242                                       NaN
# 218  BRIVA211410089529961557NBMBAMIN AFIF RAF
# 243   089529961557|1SMS|14/08/2024-14/08/2024
# 99               BFST8930393500 NBMB:CENAIDJA
# 165  NBMB AMIN AFIF RAFI TO NABILA SANDRA KUR
# 210      QRIS704267703781#9360000210043076322
# 157   NBMB AMIN AFIF RAFI TO AINI ZULFA NAWAL
#
#                                  TLBDS1  \
# 69   089529961557 00056027 000000029212
# 88                                  NaN
# 90       ESB:NBMB:0008G00F:639145826981
# 34       ESB:NBMB:0200200P:576951247832
# 86   089529961557 00050885 000000014402
# 3    089529961557 00450971 000000004242
# 73   089529961557 00861563 000000030513
# 68       ESB:NBMB:0001500F:628609323405
# 182                                 NaN
# 176                                 NaN
# 142                                 NaN
# 14                                  NaN
# 113      ESB:NBMB:0200200P:657250212067
# 242                                 NaN
# 218      ESB:NBMB:0200200P:707244009318
# 243                                 NaN
# 99       ESB:NBMB:0008G00F:644274639075
# 165      ESB:NBMB:0001500F:682378869755
# 210      ESB:NBMB:0007I00P:704267703781
# 157      ESB:NBMB:0001500F:680617649504
#
#                                      TLBDS2  \
# 69                                      NaN
# 88                                      NaN
# 90           20240123BRINIDJA010O0221835867
# 34    BRIVA 88810081219556562NBMBDNID FERXX
# 86                                      NaN
# 3                                       NaN
# 73                                      NaN
# 68                                      NaN
# 182                                     NaN
# 176                                     NaN
# 142                                     NaN
# 14                                      NaN
# 113  BRIVA 3379089529961557NBMBAmin Afif Ra
# 242                                     NaN
# 218                                     NaN
# 243                                     NaN
# 99           20240204BRINIDJA010O0219351777
# 165                                     NaN
# 210                                     NaN
# 157                                     NaN
#
#                                      REMARK_CUSTOM
# 69              089529961557 00056027 000000029212
# 88                                 Monthly Fee ATM
# 90                    BFST8930666999 NBMB:CENAIDJA
# 34         Top Up DANA FERXX 0812xxxx562 via BRImo
# 86              089529961557 00050885 000000014402
# 3               089529961557 00450971 000000004242
# 73              089529961557 00861563 000000030513
# 68           Transfer Dari Nabila Sandra via BRImo
# 182     Biaya SMS Notifikasi Sejumlah 1 Notifikasi
# 176     Biaya SMS Notifikasi Sejumlah 3 Notifikasi
# 142                                Monthly Fee ATM
# 14      Biaya SMS Notifikasi Sejumlah 1 Notifikasi
# 113        BRIVA3379089529961557NBMBAmin Afif Rafi
# 242                                      Admin Fee
# 218       BRIVA211410089529961557NBMBAMIN AFIF RAF
# 243     Biaya SMS Notifikasi Sejumlah 1 Notifikasi
# 99                    BFST8930393500 NBMB:CENAIDJA
# 165        Transfer Ke Nabila Sandra Kur via BRImo
# 210  Bayar QRIS Non BRI Merchant: QRIS704267703781
# 157         Transfer Ke Aini Zulfa Nawal via BRImo

# %%
def assessing_data(df):
    print(f"\n---TABLE INFO---\n")
    df.info()

    print(f"\n---MISSING VALUES---\n")
    print(df.isna().sum())

    print(f"\n---DUPLICATE DATA---\n")
    print(df.duplicated().sum())

    print(f"\n---STATISTICS PARAMETER---\n")
    print(df.describe())

# %%
assessing_data(adit_df)
# Out:
# ---TABLE INFO---
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  78 non-null     int64
#  1   NOREK               78 non-null     int64
#  2   TGL_TRAN            78 non-null     object
#  3   TGL_EFEKTIF         78 non-null     object
#  4   JAM_TRAN            72 non-null     float64
#  5   SEQ                 72 non-null     float64
#  6   DESK_TRAN           78 non-null     object
#  7   SALDO_AWAL_MUTASI   78 non-null     float64
#  8   MUTASI_DEBET        78 non-null     float64
#  9   MUTASI_KREDIT       78 non-null     float64
#  10  SALDO_AKHIR_MUTASI  78 non-null     float64
#  11  GLSIGN              72 non-null     object
#  12  TRUSER              72 non-null     float64
#  13  KODE_TRAN           72 non-null     float64
#  14  KODE_TRAN_TELLER    72 non-null     float64
#  15  TRREMK              71 non-null     object
#  16  TLBDS1              61 non-null     object
#  17  TLBDS2              52 non-null     object
#  18  REMARK_CUSTOM       72 non-null     object
# dtypes: float64(9), int64(2), object(8)
# memory usage: 11.7+ KB
#
# ---MISSING VALUES---
#
# ID                     0
# NOREK                  0
# TGL_TRAN               0
# TGL_EFEKTIF            0
# JAM_TRAN               6
# SEQ                    6
# DESK_TRAN              0
# SALDO_AWAL_MUTASI      0
# MUTASI_DEBET           0
# MUTASI_KREDIT          0
# SALDO_AKHIR_MUTASI     0
# GLSIGN                 6
# TRUSER                 6
# KODE_TRAN              6
# KODE_TRAN_TELLER       6
# TRREMK                 7
# TLBDS1                17
# TLBDS2                26
# REMARK_CUSTOM          6
# dtype: int64
#
# ---DUPLICATE DATA---
#
# 0
#
# ---STATISTICS PARAMETER---
#
#               ID         NOREK       JAM_TRAN           SEQ  \
# count  78.000000  7.800000e+01      72.000000  7.200000e+01
# mean    9.717949  4.791010e+14  141827.097222  1.582229e+06
# std     7.769232  1.006473e+00   51557.517393  2.817608e+06
# min     1.000000  4.791010e+14   62142.000000  1.702000e+03
# 25%     3.000000  4.791010e+14   94428.500000  4.148000e+04
# 50%     7.000000  4.791010e+14  123522.500000  1.028330e+05
# 75%    15.750000  4.791010e+14  191263.250000  1.175518e+06
# max    28.000000  4.791010e+14  231647.000000  9.000009e+06
#
#        SALDO_AWAL_MUTASI  MUTASI_DEBET  MUTASI_KREDIT  SALDO_AKHIR_MUTASI  \
# count       7.800000e+01  7.800000e+01   7.800000e+01        7.800000e+01
# mean        2.125674e+06  2.952443e+05   3.353846e+05        2.165814e+06
# std         1.920600e+06  6.813437e+05   8.597394e+05        1.909586e+06
# min         5.154780e+04  0.000000e+00   0.000000e+00        5.154780e+04
# 25%         3.332348e+05  0.000000e+00   0.000000e+00        3.689208e+05
# 50%         1.410298e+06  2.500000e+03   0.000000e+00        1.640922e+06
# 75%         3.395671e+06  2.505000e+05   0.000000e+00        3.395671e+06
# max         7.619048e+06  3.203000e+06   4.575000e+06        7.619048e+06
#
#              TRUSER  KODE_TRAN  KODE_TRAN_TELLER
# count  7.200000e+01  72.000000         72.000000
# mean   7.746357e+06   1.930556       8409.083333
# std    3.061863e+06   0.810606       2390.666085
# min    3.718510e+05   1.000000       2117.000000
# 25%    8.888068e+06   2.000000       8507.500000
# 50%    8.888291e+06   2.000000       8700.000000
# 75%    8.888528e+06   2.000000       9973.000000
# max    9.966571e+06   5.000000       9973.000000

# %%
assessing_data(alus_df)
# Out:
# ---TABLE INFO---
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253 entries, 0 to 252
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  253 non-null    int64
#  1   NOREK               253 non-null    int64
#  2   TGL_TRAN            253 non-null    object
#  3   TGL_EFEKTIF         253 non-null    object
#  4   JAM_TRAN            253 non-null    int64
#  5   SEQ                 253 non-null    int64
#  6   DESK_TRAN           253 non-null    object
#  7   SALDO_AWAL_MUTASI   253 non-null    float64
#  8   MUTASI_DEBET        253 non-null    float64
#  9   MUTASI_KREDIT       253 non-null    float64
#  10  SALDO_AKHIR_MUTASI  253 non-null    float64
#  11  GLSIGN              253 non-null    object
#  12  TRUSER              233 non-null    object
#  13  KODE_TRAN           253 non-null    int64
#  14  KODE_TRAN_TELLER    213 non-null    float64
#  15  TRREMK              233 non-null    object
#  16  TLBDS1              192 non-null    object
#  17  TLBDS2              95 non-null     object
#  18  REMARK_CUSTOM       253 non-null    object
# dtypes: float64(5), int64(5), object(9)
# memory usage: 37.7+ KB
#
# ---MISSING VALUES---
#
# ID                      0
# NOREK                   0
# TGL_TRAN                0
# TGL_EFEKTIF             0
# JAM_TRAN                0
# SEQ                     0
# DESK_TRAN               0
# SALDO_AWAL_MUTASI       0
# MUTASI_DEBET            0
# MUTASI_KREDIT           0
# SALDO_AKHIR_MUTASI      0
# GLSIGN                  0
# TRUSER                 20
# KODE_TRAN               0
# KODE_TRAN_TELLER       40
# TRREMK                 20
# TLBDS1                 61
# TLBDS2                158
# REMARK_CUSTOM           0
# dtype: int64
#
# ---DUPLICATE DATA---
#
# 0
#
# ---STATISTICS PARAMETER---
#
#                ID         NOREK       JAM_TRAN           SEQ  \
# count  253.000000  2.530000e+02     253.000000  2.530000e+02
# mean    12.652174  1.230108e+13  137295.596838  2.164927e+06
# std      7.548097  0.000000e+00   61672.332774  3.497819e+06
# min      1.000000  1.230108e+13       0.000000  0.000000e+00
# 25%      6.000000  1.230108e+13   93929.000000  2.252600e+04
# 50%     12.000000  1.230108e+13  133108.000000  1.044490e+05
# 75%     19.000000  1.230108e+13  191109.000000  4.326253e+06
# max     31.000000  1.230108e+13  235959.000000  9.894400e+06
#
#        SALDO_AWAL_MUTASI  MUTASI_DEBET  MUTASI_KREDIT  SALDO_AKHIR_MUTASI  \
# count       2.530000e+02  2.530000e+02   2.530000e+02        2.530000e+02
# mean        1.537512e+06  1.150644e+05   1.109170e+05        1.533365e+06
# std         1.811024e+06  3.909758e+05   5.924477e+05        1.811881e+06
# min         7.000000e+04  0.000000e+00   0.000000e+00        7.000000e+04
# 25%         5.115000e+05  1.500000e+03   0.000000e+00        5.115000e+05
# 50%         8.360000e+05  6.000000e+03   0.000000e+00        8.330000e+05
# 75%         1.540500e+06  1.000000e+05   0.000000e+00        1.539750e+06
# max         8.795500e+06  3.000000e+06   7.000000e+06        8.795500e+06
#
#         KODE_TRAN  KODE_TRAN_TELLER
# count  253.000000        213.000000
# mean    83.865613       8413.380282
# std    189.942780       1216.735034
# min      1.000000       2501.000000
# 25%      2.000000       8154.000000
# 50%      2.000000       8508.000000
# 75%      4.000000       8700.000000
# max    582.000000       9992.000000

# %%
assessing_data(amin_df)
# Out:
# ---TABLE INFO---
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 281 entries, 0 to 280
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  281 non-null    int64
#  1   NOREK               281 non-null    int64
#  2   TGL_TRAN            281 non-null    object
#  3   TGL_EFEKTIF         281 non-null    object
#  4   JAM_TRAN            281 non-null    int64
#  5   SEQ                 281 non-null    int64
#  6   DESK_TRAN           281 non-null    object
#  7   SALDO_AWAL_MUTASI   281 non-null    float64
#  8   MUTASI_DEBET        281 non-null    float64
#  9   MUTASI_KREDIT       281 non-null    float64
#  10  SALDO_AKHIR_MUTASI  281 non-null    float64
#  11  GLSIGN              281 non-null    object
#  12  TRUSER              249 non-null    object
#  13  KODE_TRAN           281 non-null    int64
#  14  KODE_TRAN_TELLER    219 non-null    float64
#  15  TRREMK              249 non-null    object
#  16  TLBDS1              219 non-null    object
#  17  TLBDS2              67 non-null     object
#  18  REMARK_CUSTOM       281 non-null    object
# dtypes: float64(5), int64(5), object(9)
# memory usage: 41.8+ KB
#
# ---MISSING VALUES---
#
# ID                      0
# NOREK                   0
# TGL_TRAN                0
# TGL_EFEKTIF             0
# JAM_TRAN                0
# SEQ                     0
# DESK_TRAN               0
# SALDO_AWAL_MUTASI       0
# MUTASI_DEBET            0
# MUTASI_KREDIT           0
# SALDO_AKHIR_MUTASI      0
# GLSIGN                  0
# TRUSER                 32
# KODE_TRAN               0
# KODE_TRAN_TELLER       62
# TRREMK                 32
# TLBDS1                 62
# TLBDS2                214
# REMARK_CUSTOM           0
# dtype: int64
#
# ---DUPLICATE DATA---
#
# 0
#
# ---STATISTICS PARAMETER---
#
#                ID         NOREK       JAM_TRAN           SEQ  \
# count  281.000000  2.810000e+02     281.000000  2.810000e+02
# mean    10.416370  6.787010e+14  136781.964413  1.006565e+06
# std      6.841649  2.629683e+00   66852.756462  2.684318e+06
# min      1.000000  6.787010e+14       0.000000  0.000000e+00
# 25%      5.000000  6.787010e+14   91714.000000  1.773000e+03
# 50%      9.000000  6.787010e+14  140956.000000  4.292300e+04
# 75%     15.000000  6.787010e+14  190705.000000  1.267400e+05
# max     30.000000  6.787010e+14  235959.000000  9.295206e+06
#
#        SALDO_AWAL_MUTASI  MUTASI_DEBET  MUTASI_KREDIT  SALDO_AKHIR_MUTASI  \
# count       2.810000e+02  2.810000e+02   2.810000e+02        2.810000e+02
# mean        8.389935e+05  1.659982e+05   1.659440e+05        8.389392e+05
# std         1.083809e+06  5.817941e+05   8.237038e+05        1.083849e+06
# min         2.901427e+04  0.000000e+00   0.000000e+00        2.901427e+04
# 25%         1.836373e+05  7.500000e+02   0.000000e+00        1.836373e+05
# 50%         5.451293e+05  1.600000e+04   0.000000e+00        5.451293e+05
# 75%         1.250014e+06  2.000000e+05   0.000000e+00        1.250014e+06
# max         1.268378e+07  7.845000e+06   1.204500e+07        1.268378e+07
#
#         KODE_TRAN  KODE_TRAN_TELLER
# count  281.000000        219.000000
# mean   115.366548       7112.452055
# std    215.267668       2301.761131
# min      1.000000       2501.000000
# 25%      2.000000       6669.000000
# 50%      2.000000       8506.000000
# 75%      4.000000       8508.000000
# max    582.000000       9973.000000

# %% [markdown]
# ### **CLEANING DATA FOR DATASET**

# %%
def preprocess_data_from_bank(data):
  data['amount'] = data['MUTASI_DEBET'] + data['MUTASI_KREDIT']

  data.drop(["ID","NOREK","TGL_EFEKTIF","JAM_TRAN","SEQ","DESK_TRAN","SALDO_AWAL_MUTASI",
             "MUTASI_DEBET", "MUTASI_KREDIT", "SALDO_AKHIR_MUTASI","TRUSER","KODE_TRAN",
             "KODE_TRAN_TELLER","TRREMK", "TLBDS1","TLBDS2","REMARK_CUSTOM"],
            axis = 1, inplace= True)

  data.rename(columns={'TGL_TRAN':'date','GLSIGN':'transaction_type'}, inplace=True)

  data['transaction_type'] = data['transaction_type'].replace({'Cr': 'Income', 'Db': 'Expense'})

  data['date'] = pd.to_datetime(data['date']).dt.date
  data['amount'] = pd.to_numeric(data['amount'])
  data['transaction_type'] = data['transaction_type'].astype('category')

  data.dropna(inplace=True)

  data.sort_values(by='date', ascending=True)

  return data

# %%
preprocess_data_from_bank(adit_df)
# Out:
#           date transaction_type     amount
# 0   2024-01-29           Income  2735000.0
# 1   2024-01-30           Income   300000.0
# 2   2024-01-30          Expense  2800000.0
# 3   2024-01-30          Expense     2500.0
# 4   2024-01-31          Expense   240000.0
# ..         ...              ...        ...
# 73  2024-11-18           Income   700000.0
# 74  2024-11-18          Expense   437000.0
# 75  2024-11-18          Expense     2500.0
# 76  2024-11-18          Expense   150000.0
# 77  2024-11-18          Expense     2500.0
#
# [72 rows x 3 columns]

# %%
preprocess_data_from_bank(alus_df)
# Out:
#            date transaction_type    amount
# 0    2024-01-02          Expense  680000.0
# 1    2024-01-02          Expense    2500.0
# 2    2024-01-02          Expense  100000.0
# 3    2024-01-02          Expense    1500.0
# 4    2024-01-02          Expense   15000.0
# ..          ...              ...       ...
# 248  2024-11-13           Income   50000.0
# 249  2024-11-14          Expense   30000.0
# 250  2024-11-15          Expense   20000.0
# 251  2024-11-15           Income  300000.0
# 252  2024-11-15          Expense   90000.0
#
# [253 rows x 3 columns]

# %%
preprocess_data_from_bank(amin_df)
# Out:
#            date transaction_type     amount
# 0    2023-09-01           Income  1200000.0
# 1    2023-09-04          Expense   200000.0
# 2    2023-09-04           Income   100000.0
# 3    2023-09-04          Expense   100000.0
# 4    2023-09-04          Expense   100000.0
# ..          ...              ...        ...
# 276  2024-11-05           Income   500000.0
# 277  2024-11-05          Expense   700000.0
# 278  2024-11-10          Expense     3000.0
# 279  2024-11-16          Expense     2500.0
# 280  2024-11-16          Expense     5500.0
#
# [281 rows x 3 columns]

# %%
data = pd.concat([adit_df, alus_df, amin_df]).sort_values(by='date', ascending=True)
data['date'] = data['date'].astype(str)

with open('merger_dataset.csv', 'w') as csv_file:
    csv_file.write(data.to_csv(index=False))

# %% [markdown]
# ### **CLEANING DATA FOR CASHFLOW ANALYSIS AND ANOMALY**

# %%
def preprocess_clean_data(data):

    data['income'] = data.apply(lambda x: x['amount'] if x['transaction_type'] == 'Income' else 0, axis=1)
    data['expense'] = data.apply(lambda x: x['amount'] if x['transaction_type'] == 'Expense' else 0, axis=1)

    income_df = data[data['transaction_type'] == 'Income'][['date', 'amount']].copy()
    expense_df = data[data['transaction_type'] == 'Expense'][['date', 'amount']].copy()

    income_df = income_df[income_df['amount'] > 0]
    expense_df = expense_df[expense_df['amount'] > 0]

    return income_df, expense_df

# %%
merger_df = pd.read_csv("merger_dataset.csv")

# %%
income_df, expense_df = preprocess_clean_data(merger_df)

# %%
income_df.head()
# Out:
#           date     amount
# 2   2023-08-08   190000.0
# 3   2023-08-11  1200000.0
# 12  2023-09-01  1200000.0
# 14  2023-09-04   100000.0
# 19  2023-09-14    37000.0

# %%
expense_df.head()
# Out:
#          date    amount
# 0  2023-08-03   20000.0
# 1  2023-08-08  186450.0
# 4  2023-08-12  384000.0
# 5  2023-08-12  400000.0
# 6  2023-08-14  150000.0

# %% [markdown]
# #### **Export Data to CSV**

# %%
with open('pemasukan.csv', 'w') as csv_file:
    income_df['date'] = pd.to_datetime(income_df['date'])
    income_df['date'] = income_df['date'].dt.strftime('%Y-%m-%d')
    income_df.to_csv(csv_file, index=False)

with open('pengeluaran.csv', 'w') as csv_file:
    expense_df['date'] = pd.to_datetime(expense_df['date'])
    expense_df['date'] = expense_df['date'].dt.strftime('%Y-%m-%d')
    expense_df.to_csv(csv_file, index=False)

# %% [markdown]
# #### **Export Data to JSON**

# %%
import json

merger_df = pd.read_csv("merger_dataset.csv")
merger_df.to_json('merger_dataset.json', orient='records', indent=1)

income_df = pd.read_csv("pemasukan.csv")
income_df.to_json('pemasukan.json', orient='records', indent=1)

expense_df = pd.read_csv("pengeluaran.csv")
expense_df.to_json('pengeluaran.json', orient='records', indent=1)

# %% [markdown]
# # **CASHFLOW ANALYSIS**

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

from matplotlib.dates import DateFormatter
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ### **DATA VISUALIZATION**

# %%
def preprocess_data_visualization(data):

  data = pd.DataFrame(pd.read_json(data))

  data['total_income'] = data.apply(lambda x: x['amount'] if x['transaction_type'] == 'Income' else 0, axis=1)
  data['total_expense'] = data.apply(lambda x: x['amount'] if x['transaction_type'] == 'Expense' else 0, axis=1)

  data['net_cashflow'] = data['total_income'] - data['total_expense']

  data['month'] = pd.to_datetime(data['date']).dt.to_period('M')

  summary = data.groupby('month').agg(
    total_income = ('total_income', 'sum'),
    total_expense = ('total_expense', 'sum'),
    net_cashflow = ('net_cashflow', 'sum')
  ).reset_index()

  summary['month'] = summary['month'].dt.to_timestamp()

  return summary

# %%
data = preprocess_data_visualization('merger_dataset.json')
data.head(10)
# Out:
#        month  total_income  total_expense  net_cashflow
# 0 2023-08-01       1390000        1412950        -22950
# 1 2023-09-01       1607000        1443530        163470
# 2 2023-10-01       1510000        1652785       -142785
# 3 2023-11-01       1200000        1077068        122932
# 4 2023-12-01       1750000        1829508        -79508
# 5 2024-01-01       9735000       11400361      -1665361
# 6 2024-02-01      19201015       18971500        229515
# 7 2024-03-01       3620000        2670818        949182
# 8 2024-04-01       6250101        4098822       2151279
# 9 2024-05-01       4527000        6434944      -1907944

# %%
#Min-Max Scaler Initialization

income_scaler = MinMaxScaler(feature_range=(0, 1))
expense_scaler = MinMaxScaler(feature_range=(0, 1))
cashflow_scaler = MinMaxScaler(feature_range=(0, 1))

# %%
def time_series(data):

  total_income = income_scaler.fit_transform(data[['total_income']])
  total_expense = expense_scaler.fit_transform(data[['total_expense']])
  net_cashflow = cashflow_scaler.fit_transform(data[['net_cashflow']])

  time = data['month'].tolist()
  income = total_income.tolist()
  expense = total_expense.tolist()
  net_cashflow = net_cashflow.tolist()

  return time, income, expense, net_cashflow

# %%
TIME, INCOME, EXPENSE, NET_CASHFLOW = time_series(data)

INCOME_SCALED = income_scaler.inverse_transform(np.array(INCOME).reshape(-1,1)).flatten()
EXPENSE_SCALED = expense_scaler.inverse_transform(np.array(EXPENSE).reshape(-1,1)).flatten()
NET_CASHFLOW_SCALED = cashflow_scaler.inverse_transform(np.array(NET_CASHFLOW).reshape(-1,1)).flatten()

# %%
def plot_value(time, value, label):
  plt.plot(time, value, label = label)
  formatter = ticker.ScalarFormatter()
  formatter.set_scientific(False)
  plt.xlabel("Transaction Per Month")
  plt.ylabel("Total Amount")
  plt.gca().xaxis.set_major_formatter(DateFormatter("%Y-%m"))
  plt.gca().yaxis.set_major_formatter(formatter)
  plt.legend()
  plt.gcf().autofmt_xdate()
  plt.show()

# %%
plot_value(TIME, INCOME_SCALED, "Income")

# %%
plot_value(TIME, EXPENSE_SCALED, "Expense")

# %%
plot_value(TIME, NET_CASHFLOW_SCALED, "Net Cashflow")

# %% [markdown]
# # **UNUSUAL SPENDING PATTERN (AUTOENCODER) MODEL**

# %%
# !pip install tensorflow
# !pip install tensorflowjs
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.68.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.5.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.5.0->tensorflow) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Requirement already satisfied: tensorflowjs in /usr/local/lib/python3.10/dist-packages (4.22.0)
# Requirement already satisfied: flax>=0.7.2 in /usr/local/lib/python3.10/dist-packages (from tensorflowjs) (0.8.5)
# Requirement already satisfied: importlib_resources>=5.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflowjs) (6.4.5)
# Requirement already satisfied: jax>=0.4.13 in /usr/local/lib/python3.10/dist-packages (from tensorflowjs) (0.4.33)
# Requirement already satisfied: jaxlib>=0.4.13 in /usr/local/lib/python3.10/dist-packages (from tensorflowjs) (0.4.33)
# Requirement already satisfied: tensorflow<3,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from tensorflowjs) (2.18.0)
# Requirement already satisfied: tf-keras>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from tensorflowjs) (2.18.0)
# Requirement already satisfied: tensorflow-decision-forests>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from tensorflowjs) (1.11.0)
# Requirement already satisfied: six<2,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from tensorflowjs) (1.17.0)
# Requirement already satisfied: tensorflow-hub>=0.16.1 in /usr/local/lib/python3.10/dist-packages (from tensorflowjs) (0.16.1)
# Requirement already satisfied: packaging~=23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflowjs) (23.2)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.10/dist-packages (from flax>=0.7.2->tensorflowjs) (1.26.4)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.10/dist-packages (from flax>=0.7.2->tensorflowjs) (1.1.0)
# Requirement already satisfied: optax in /usr/local/lib/python3.10/dist-packages (from flax>=0.7.2->tensorflowjs) (0.2.4)
# Requirement already satisfied: orbax-checkpoint in /usr/local/lib/python3.10/dist-packages (from flax>=0.7.2->tensorflowjs) (0.6.4)
# Requirement already satisfied: tensorstore in /usr/local/lib/python3.10/dist-packages (from flax>=0.7.2->tensorflowjs) (0.1.69)
# Requirement already satisfied: rich>=11.1 in /usr/local/lib/python3.10/dist-packages (from flax>=0.7.2->tensorflowjs) (13.9.4)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.10/dist-packages (from flax>=0.7.2->tensorflowjs) (4.12.2)
# Requirement already satisfied: PyYAML>=5.4.1 in /usr/local/lib/python3.10/dist-packages (from flax>=0.7.2->tensorflowjs) (6.0.2)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from jax>=0.4.13->tensorflowjs) (0.4.1)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from jax>=0.4.13->tensorflowjs) (3.4.0)
# Requirement already satisfied: scipy>=1.10 in /usr/local/lib/python3.10/dist-packages (from jax>=0.4.13->tensorflowjs) (1.13.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (18.1.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (75.1.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (2.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (1.68.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (3.5.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (3.12.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (0.37.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from tensorflow-decision-forests>=1.5.0->tensorflowjs) (2.2.2)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from tensorflow-decision-forests>=1.5.0->tensorflowjs) (0.45.1)
# Requirement already satisfied: wurlitzer in /usr/local/lib/python3.10/dist-packages (from tensorflow-decision-forests>=1.5.0->tensorflowjs) (3.1.1)
# Requirement already satisfied: ydf in /usr/local/lib/python3.10/dist-packages (from tensorflow-decision-forests>=1.5.0->tensorflowjs) (0.9.0)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.5.0->tensorflow<3,>=2.13.0->tensorflowjs) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.5.0->tensorflow<3,>=2.13.0->tensorflowjs) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow<3,>=2.13.0->tensorflowjs) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow<3,>=2.13.0->tensorflowjs) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow<3,>=2.13.0->tensorflowjs) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow<3,>=2.13.0->tensorflowjs) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1->flax>=0.7.2->tensorflowjs) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1->flax>=0.7.2->tensorflowjs) (2.18.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.19,>=2.18->tensorflow<3,>=2.13.0->tensorflowjs) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.19,>=2.18->tensorflow<3,>=2.13.0->tensorflowjs) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.19,>=2.18->tensorflow<3,>=2.13.0->tensorflowjs) (3.1.3)
# Requirement already satisfied: chex>=0.1.87 in /usr/local/lib/python3.10/dist-packages (from optax->flax>=0.7.2->tensorflowjs) (0.1.87)
# Requirement already satisfied: etils[epy] in /usr/local/lib/python3.10/dist-packages (from optax->flax>=0.7.2->tensorflowjs) (1.11.0)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.10/dist-packages (from orbax-checkpoint->flax>=0.7.2->tensorflowjs) (1.6.0)
# Requirement already satisfied: humanize in /usr/local/lib/python3.10/dist-packages (from orbax-checkpoint->flax>=0.7.2->tensorflowjs) (4.11.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->tensorflow-decision-forests>=1.5.0->tensorflowjs) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->tensorflow-decision-forests>=1.5.0->tensorflowjs) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->tensorflow-decision-forests>=1.5.0->tensorflowjs) (2024.2)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from chex>=0.1.87->optax->flax>=0.7.2->tensorflowjs) (0.12.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1->flax>=0.7.2->tensorflowjs) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow<3,>=2.13.0->tensorflowjs) (3.0.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax>=0.7.2->tensorflowjs) (2024.10.0)
# Requirement already satisfied: zipp in /usr/local/lib/python3.10/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax>=0.7.2->tensorflowjs) (3.21.0)

# %%
import tensorflow as tf
import tensorflowjs as tfjs

from tensorflow.keras import layers, models, optimizers
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
# Out:
# <p style="margin:0px;">🌲 Try <a href="https://ydf.readthedocs.io/en/latest/" target="_blank">YDF</a>, the successor of
#     <a href="https://www.tensorflow.org/decision_forests" target="_blank">TensorFlow
#         Decision Forests</a> using the same algorithms but with more features and faster
#     training!
# </p>
# <div style="display: flex; flex-wrap: wrap; margin:5px;max-width: 880px;">
#     <div style="flex: 1; border-radius: 10px; background-color: F0F0F0; padding: 5px;">
#         <p
#             style="font-weight: bold; margin:0px;text-align: center;border-bottom: 1px solid #C0C0C0;margin-bottom: 4px;">
#             Old code</p>
#         <pre style="overflow-wrap: anywhere; overflow: auto; margin:0px;font-size: 9pt;">
# import tensorflow_decision_forests as tfdf
#
# tf_ds = tfdf.keras.pd_dataframe_to_tf_dataset(ds, label="l")
# model = tfdf.keras.RandomForestModel(label="l")
# model.fit(tf_ds)
# </pre>
#     </div>
#     <div style="width: 5px;"></div>
#     <div style="flex: 1; border-radius: 10px; background-color: F0F0F0; padding: 5px;">
#         <p
#             style="font-weight: bold; margin:0px;text-align: center;border-bottom: 1px solid #C0C0C0;margin-bottom: 4px;">
#             New code</p>
#         <pre style="overflow-wrap: anywhere; overflow: auto; margin:0px;font-size: 9pt;">
# import ydf
#
# model = ydf.RandomForestLearner(label="l").train(ds)
# </pre>
#     </div>
# </div>
# <p style="margin:0px;font-size: 9pt;">(Learn more in the <a
#         href="https://ydf.readthedocs.io/en/latest/tutorial/migrating_to_ydf/" target="_blank">migration
#         guide</a>)</p>

# %%
def preprocess_data(data):

    data['date'] = pd.to_datetime(data['date'])
    data['day_of_week'] = data['date'].dt.dayofweek # Day of the week (0=Monday, 6=Sunday)
    data['month'] = data['date'].dt.month           # Month of the year (1=January, 12=December)
    data['day_of_month'] = data['date'].dt.day      # Day of the month (1-31)

    features = ['amount', 'day_of_week', 'month', 'day_of_month']
    data = data[features]

    scaler = MinMaxScaler()
    data_scaled = scaler.fit_transform(data)

    return data_scaled, data, scaler

# %%
def build_autoencoder(input_dim):

    autoencoder = models.Sequential([
        layers.Input(shape=(input_dim,)),       # Input layer
        layers.Dense(32, activation='relu'),    # Encoder
        layers.Dense(16, activation='relu'),    # Encoder
        layers.Dense(8, activation='relu'),     # Bottleneck
        layers.Dense(16, activation='relu'),    # Decoder
        layers.Dense(32, activation='relu'),    # Decoder
        layers.Dense(input_dim, activation='sigmoid')  # Output layer
    ])
    autoencoder.compile(optimizer=optimizers.Adam(), loss='mse')

    return autoencoder

# %%
def detect_anomalies(autoencoder, data_scaled, original_data, scaler, percentile=95):

    # Reconstruct
    reconstructed = autoencoder.predict(data_scaled)
    mse = np.mean(np.power(data_scaled - reconstructed, 2), axis=1)

    # Threshold
    threshold = np.percentile(mse, percentile)

    # Flag anomalies
    original_data['reconstruction_error'] = mse
    original_data['is_anomaly'] = mse > threshold

    # Filter anomalies
    anomalies = original_data[original_data['is_anomaly']]

    return original_data, anomalies

# %%
def plot_results(processed_data, anomalies):

    plt.figure(figsize=(10, 6))

    normal_data = processed_data[~processed_data['is_anomaly']]
    plt.scatter(normal_data.index, normal_data['amount'], color='blue', label='Normal', alpha=0.6)

    plt.scatter(anomalies.index, anomalies['amount'], color='red', label='Anomaly', alpha=0.8)

    plt.title('Anomaly Detection in Financial Transactions')
    plt.xlabel('Index')
    plt.ylabel('Amount')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
def main_pipeline(data, epochs=50, batch_size=16, percentile=95):

    # Preprocess data
    data_scaled, processed_data, scaler = preprocess_data(data)

    # Build autoencoder
    input_dim = data_scaled.shape[1]
    autoencoder = build_autoencoder(input_dim)

    # Train autoencoder
    history = autoencoder.fit(data_scaled, data_scaled, epochs=epochs, batch_size=batch_size, shuffle=True, verbose=1)

    # Detect anomalies
    processed_data, anomalies = detect_anomalies(autoencoder, data_scaled, processed_data, scaler, percentile=percentile)

    # Results
    plot_results(processed_data, anomalies)

    return autoencoder, processed_data, anomalies, scaler

# %%
def predict_pipeline(model, new_data, scaler, percentile):

    # Preprocess new data
    if 'day_of_week' not in new_data.columns:
        new_data['date'] = pd.to_datetime(new_data['date'])
        new_data['day_of_week'] = new_data['date'].dt.dayofweek
        new_data['month'] = new_data['date'].dt.month
        new_data['day_of_month'] = new_data['date'].dt.day
        new_data = new_data[['amount', 'day_of_week', 'month', 'day_of_month']]

    # Normalize data
    new_data_scaled = scaler.transform(new_data)

    # Reconstruct
    reconstructed = model.predict(new_data_scaled)
    mse = np.mean(np.power(new_data_scaled - reconstructed, 2), axis=1)

    # Threshold
    threshold = np.percentile(mse, percentile)

    # Flag anomalies
    new_data['reconstruction_error'] = mse
    new_data['is_anomaly'] = mse > threshold

    # Filter anomalies
    anomalies = new_data[new_data['is_anomaly']]

    # Results
    plot_results(new_data, anomalies)

    return new_data, anomalies

# %%
def training_pipeline(model, data, scaler, epochs=100, batch_size=16):

    # Preprocess data
    if 'day_of_week' not in data.columns:
        data['date'] = pd.to_datetime(data['date'])
        data['day_of_week'] = data['date'].dt.dayofweek
        data['month'] = data['date'].dt.month
        data['day_of_month'] = data['date'].dt.day
        data = data[['amount', 'day_of_week', 'month', 'day_of_month']]

    data_scaled = scaler.transform(data)

    # Retrain autoencoder
    model.fit(data_scaled, data_scaled, epochs=epochs, batch_size=batch_size, shuffle=True, verbose=1)

    return model

# %%
if __name__ == "__main__":

    data = pd.read_json('pengeluaran.json')

    # Run the pipeline
    autoencoder, processed_data, anomalies, scaler = main_pipeline(data, epochs=100, batch_size=4, percentile=99)

    # Display results
    print("Processed Data with Anomaly Status:")
    print(processed_data)

    print("\nDetected Anomalies:")
    print(anomalies)
# Out:
# Epoch 1/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1167
# Epoch 2/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0520
# Epoch 3/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0226
# Epoch 4/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0109
# Epoch 5/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0036
# Epoch 6/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0026
# Epoch 7/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0037
# Epoch 8/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0021
# Epoch 9/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0028
# Epoch 10/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0021
# Epoch 11/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029
# Epoch 12/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0021
# Epoch 13/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0022
# Epoch 14/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0029
# Epoch 15/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0018
# Epoch 16/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0021
# Epoch 17/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0023
# Epoch 18/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0019
# Epoch 19/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0019
# Epoch 20/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0020
# Epoch 21/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0018
# Epoch 22/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0017
# Epoch 23/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0016
# Epoch 24/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0021
# Epoch 25/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0021
# Epoch 26/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0019
# Epoch 27/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0017
# Epoch 28/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0015
# Epoch 29/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0018
# Epoch 30/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0016
# Epoch 31/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0019
# Epoch 32/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0015
# Epoch 33/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0012
# Epoch 34/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0013
# Epoch 35/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0012
# Epoch 36/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0013
# Epoch 37/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0013
# Epoch 38/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0015
# Epoch 39/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0013
# Epoch 40/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0015
# Epoch 41/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0017
# Epoch 42/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0011
# Epoch 43/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0013
# Epoch 44/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0014
# Epoch 45/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0018
# Epoch 46/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0016
# Epoch 47/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0013
# Epoch 48/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0013
# Epoch 49/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011
# Epoch 50/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0013
# Epoch 51/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0014
# Epoch 52/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0012
# Epoch 53/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0016
# Epoch 54/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0015
# Epoch 55/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0018
# Epoch 56/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0012
# Epoch 57/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0012
# Epoch 58/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011
# Epoch 59/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0016
# Epoch 60/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0015
# Epoch 61/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0015
# Epoch 62/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0013
# Epoch 63/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0012
# Epoch 64/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0013
# Epoch 65/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0013
# Epoch 66/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.9569e-04
# Epoch 67/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011
# Epoch 68/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0015
# Epoch 69/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0012
# Epoch 70/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0012
# Epoch 71/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0015
# Epoch 72/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0016
# Epoch 73/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0014
# Epoch 74/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0012
# Epoch 75/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0013
# Epoch 76/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0015
# Epoch 77/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0010
# Epoch 78/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0012
# Epoch 79/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0014
# Epoch 80/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0013
# Epoch 81/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0010
# Epoch 82/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0012
# Epoch 83/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0010
# Epoch 84/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.1416e-04
# Epoch 85/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.3514e-04
# Epoch 86/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.6420e-04
# Epoch 87/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.0309e-04
# Epoch 88/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.2368e-04
# Epoch 89/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.7847e-04
# Epoch 90/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.4737e-04
# Epoch 91/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.7027e-04
# Epoch 92/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.5446e-04
# Epoch 93/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.4143e-04
# Epoch 94/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.8852e-04
# Epoch 95/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.0728e-04
# Epoch 96/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.2023e-04
# Epoch 97/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.3401e-04
# Epoch 98/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.6971e-04
# Epoch 99/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.7492e-04
# Epoch 100/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.8361e-04
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Processed Data with Anomaly Status:
#      amount  day_of_week  month  day_of_month  reconstruction_error  \
# 0     20000            3      8             3              0.000140
# 1    186450            1      8             8              0.000056
# 2    384000            5      8            12              0.000291
# 3    400000            5      8            12              0.000312
# 4    150000            0      8            14              0.000086
# ..      ...          ...    ...           ...                   ...
# 494    5500            5     11            16              0.000176
# 495  437000            0     11            18              0.000145
# 496    2500            0     11            18              0.000172
# 497  150000            0     11            18              0.000061
# 498    2500            0     11            18              0.000172
#
#      is_anomaly
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# ..          ...
# 494       False
# 495       False
# 496       False
# 497       False
# 498       False
#
# [499 rows x 6 columns]
#
# Detected Anomalies:
#       amount  day_of_week  month  day_of_month  reconstruction_error  \
# 49       500            6     12            10              0.002919
# 246   900000            6      5            19              0.003659
# 292    33000            6      6            30              0.002812
# 293     1500            6      6            30              0.002847
# 463  1000000            6     11             3              0.003880
#
#      is_anomaly
# 49         True
# 246        True
# 292        True
# 293        True
# 463        True

# %%
pf_data = pd.read_json('pengeluaran.json')

predict_pipeline(model=autoencoder, new_data=pf_data, scaler=scaler, percentile=99)
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# (     amount  day_of_week  month  day_of_month  reconstruction_error  \
#  0     20000            3      8             3              0.000140
#  1    186450            1      8             8              0.000056
#  2    384000            5      8            12              0.000291
#  3    400000            5      8            12              0.000312
#  4    150000            0      8            14              0.000086
#  ..      ...          ...    ...           ...                   ...
#  494    5500            5     11            16              0.000176
#  495  437000            0     11            18              0.000145
#  496    2500            0     11            18              0.000172
#  497  150000            0     11            18              0.000061
#  498    2500            0     11            18              0.000172
#
#       is_anomaly
#  0         False
#  1         False
#  2         False
#  3         False
#  4         False
#  ..          ...
#  494       False
#  495       False
#  496       False
#  497       False
#  498       False
#
#  [499 rows x 6 columns],
#        amount  day_of_week  month  day_of_month  reconstruction_error  \
#  49       500            6     12            10              0.002919
#  246   900000            6      5            19              0.003659
#  292    33000            6      6            30              0.002812
#  293     1500            6      6            30              0.002847
#  463  1000000            6     11             3              0.003880
#
#       is_anomaly
#  49         True
#  246        True
#  292        True
#  293        True
#  463        True  )

# %%
pf_data = pd.read_json('pemasukan.json')

predict_pipeline(model=autoencoder, new_data=pf_data, scaler=scaler, percentile=99)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# (      amount  day_of_week  month  day_of_month  reconstruction_error  \
#  0     190000            1      8             8              0.000055
#  1    1200000            4      8            11              0.002400
#  2    1200000            4      9             1              0.004260
#  3     100000            0      9             4              0.000059
#  4      37000            3      9            14              0.000178
#  ..       ...          ...    ...           ...                   ...
#  102  2500000            3     11             7              0.005343
#  103    40000            1     11            12              0.000349
#  104    50000            2     11            13              0.000689
#  105   300000            4     11            15              0.000014
#  106   700000            0     11            18              0.000505
#
#       is_anomaly
#  0         False
#  1         False
#  2         False
#  3         False
#  4         False
#  ..          ...
#  102       False
#  103       False
#  104       False
#  105       False
#  106       False
#
#  [107 rows x 6 columns],
#        amount  day_of_week  month  day_of_month  reconstruction_error  \
#  20  12045000            4      2             2              0.103730
#  57   7000000            5      7            13              0.035317
#
#      is_anomaly
#  20        True
#  57        True  )

# %%
pf_data = pd.read_json('pengeluaran_new.json')

predict_pipeline(model=autoencoder, new_data=pf_data, scaler=scaler, percentile=99)
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# (          amount  day_of_week  month  day_of_month  reconstruction_error  \
#  0      176260.15            0      1             1              0.000961
#  1    19790635.60            1      1             2              0.725097
#  2      384250.30            1      1             2              0.000185
#  3      186572.40            3      1             4              0.000174
#  4      410110.25            4      1             5              0.000661
#  ..           ...          ...    ...           ...                   ...
#  683    390754.95            0      9            23              0.000260
#  684    530842.90            5      9            28              0.000412
#  685     67743.55            5      9            28              0.000245
#  686     27763.75            0      9            30              0.001523
#  687   1189875.00            0      9            30              0.002813
#
#       is_anomaly
#  0         False
#  1         False
#  2         False
#  3         False
#  4         False
#  ..          ...
#  683       False
#  684       False
#  685       False
#  686       False
#  687       False
#
#  [688 rows x 6 columns],
#             amount  day_of_week  month  day_of_month  reconstruction_error  \
#  148  1.269200e+08            4      5            11             58.088182
#  331  1.918364e+07            4     11             2              0.943109
#  434  3.014350e+07            3      1            31              2.322923
#  495  2.463279e+07            0      4             1              1.466444
#  579  1.459580e+08            3      6            20             78.012562
#  659  2.205822e+07            4      9             6              1.210850
#  677  2.548649e+07            2      9            18              1.630625
#
#       is_anomaly
#  148        True
#  331        True
#  434        True
#  495        True
#  579        True
#  659        True
#  677        True  )

# %%
pf_data = pd.read_json('pemasukan_new.json')

predict_pipeline(model=autoencoder, new_data=pf_data, scaler=scaler, percentile=99)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# (          amount  day_of_week  month  day_of_month  reconstruction_error  \
#  0    36459197.85            2      1             3              3.581705
#  1    31730000.00            4      1            12              2.517981
#  2    31730000.00            4      1            19              2.545538
#  3     8804916.35            0      1            22              0.086082
#  4     4915135.65            0      1            22              0.020553
#  ..           ...          ...    ...           ...                   ...
#  113  35696250.00            4      9            13              3.712679
#  114   1436893.05            0      9            16              0.002148
#  115   2952952.45            1      9            17              0.001025
#  116    149606.95            4      9            20              0.000176
#  117  35696250.00            4      9            27              3.688200
#
#       is_anomaly
#  0         False
#  1         False
#  2         False
#  3         False
#  4         False
#  ..          ...
#  113       False
#  114       False
#  115       False
#  116       False
#  117       False
#
#  [118 rows x 6 columns],
#           amount  day_of_week  month  day_of_month  reconstruction_error  \
#  99   35696250.0            4      7             5              3.729082
#  105  35696250.0            4      8             2              3.796185
#
#       is_anomaly
#  99         True
#  105        True  )

# %% [markdown]
# #### **Convert Autoencoder Model to TFJS**

# %%
saved_model_path = "./my-autoencoder.h5"

autoencoder.save(saved_model_path)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Tensorflowjs converter

from tensorflow.keras.models import load_model
from tensorflow.keras.losses import mse

model = load_model('my-autoencoder.h5', custom_objects={'mse': mse})
tfjs.converters.save_keras_model(model, './')

with open('my-autoencoder.json', 'w') as json_file:
    json_file.write(model.to_json())
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# failed to lookup keras version from the file,
#     this is likely a weight only file

# %%
import pickle

scaler_pickle_path = "scaler.pkl"
with open(scaler_pickle_path, 'wb') as f:
    pickle.dump(scaler, f)
